# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path
import matplotlib.pyplot as plt
import geoviews


# Import API key
geoapify_key = "4de3692f5d3041f8aeaf76cc55cf1d50"
EV_final_path = Path("Final_Resource/EV_final.csv")
EV_final_df = pd.read_csv(EV_final_path)
EV_final_df.head()
# Out:
#         State  Registrations of EV 2019  Registrations of EV 2020  \
# 0     Alabama                       722                    2890.0
# 1      Alaska                        87                     940.0
# 2     Arizona                      6637                   28770.0
# 3    Arkansas                       370                    1330.0
# 4  California                    100549                  425300.0
#
#    Registrations of EV 2021   Total EV YOY(2020-2021)Growth Percentage  \
# 0                    4750.0     8362.0                          64.40%
# 1                    1290.0     2317.0                          37.23%
# 2                   40740.0    76147.0                          41.61%
# 3                    2390.0     4090.0                          79.70%
# 4                  563070.0  1088919.0                          32.40%
#
#    2019 - No. EV charge outlets  2020 - No. EV charge outlets  \
# 0                         506.0                         596.0
# ...

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = EV_final_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size= "Total EV",
    color = "State",
    scale = 0.05,
    title = "Total_ev_registrations(2019-2021)",
    hover_cols=["Registrations of EV 2019","Registrations of EV 2020","Registrations of EV 2021"]
    
)
hvplot.save(map_plot_1,'Output_Data/EV_registrations.png')
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State,Total EV,Registrations of EV 2019,Registrations of EV 2020,Registrations of EV 2021)

# %%
#coverting the YOY Growth column to float from string format by creating new column
new_values=EV_final_df["YOY(2020-2021)Growth Percentage"].str.strip("%").astype(float)
EV_final_df["YOY(2020-2021)Growth Percentage"]=new_values

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = EV_final_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size= "YOY(2020-2021)Growth Percentage",
    color = "State",
    scale = 1,
    hover_cols= ["Registrations of EV 2019","Registrations of EV 2020","Registrations of EV 2021","Total_EV"],
    title = "(2020-2021) Registrations Growth Percentage"
    
)

# Display the map
hvplot.save(map_plot_2,'Output_Data/YOY(2020-2021)Growth_Percentage.png')
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State,YOY(2020-2021)Growth Percentage,Registrations of EV 2019,Registrations of EV 2020,Registrations of EV 2021)

# %%
# %%capture --no-display

# Configure the map plot
map_plot_3 = EV_final_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size= "Total charging outlets",
    color = "State",
    scale = 0.1,
    hover_cols=["Total EV","YOY(2020-2021)Growth Percentage","EV:Charger outlets"],
    title = "Total_charging_outlets"
    
)

# Display and save the map
hvplot.save(map_plot_3,'Output_Data/Total_charging_outlets.png')
map_plot_3
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State,Total charging outlets,Total EV,YOY(2020-2021)Growth Percentage,EV:Charger outlets)
