# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
from scipy.stats import linregress
import scipy.stats as st

# %%
# Import data source 
# (Ref:Source: US Department of Energy, https://afdc.energy.gov/stations/states, accessed 10 July 2023)
evdata19_df = pd.read_csv("Resources/Original_2019_historical-ev-station-counts.csv")

# Print dataframe
evdata19_df.head()
# Out:
#   Station Counts by State and Fuel Type Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                 State  Biodiesel        CNG        E85
# 1                                   NaN        NaN        NaN        NaN
# 2                                   NaN        NaN        NaN        NaN
# 3                               Alabama         10         27         34
# 4                                   NaN        NaN        NaN        NaN
#
#                     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0                          NaN        NaN        LNG        NaN      Total
# 1                     Electric        NaN        NaN        NaN        NaN
# 2  (stations/charging outlets)   Hydrogen        NaN    Propane        NaN
# 3                    195 / 506          0          2         72        651
# 4                          NaN        NaN        NaN        NaN        NaN

# %%
# Set first row as header & reprint dataframe
# Code Ref:  Zach, 4 August 2022, Statology, "How to set first row as header", 
# https://www.statology.org/pandas-set-first-row-as-header/), accessed 12 July 2023

evdata19_df.columns = evdata19_df.iloc[0]
evdata19_df = evdata19_df[1:]
evdata19_df.head()

# Drop rows from "State" column with "Nan" values
evdata19_df.dropna(subset = ["State"], inplace=True)
list(evdata19_df.columns)
# Out:
# ['State', 'Biodiesel', 'CNG', 'E85', nan, nan, 'LNG', nan, 'Total']

# %%
# Rename column "Nan" to "No.EV Charge Stations / No. EV charge outlets"
# Code Ref: tozCSS, 15 September 2019, StackOverflow, "Rename Pandas dataframe with Nan header"
# (https://stackoverflow.com/questions/45545675/rename-pandas-dataframe-with-nan-header), accessed 12 July 2023

evbase19_df = evdata19_df.rename(columns=str).rename(columns={"nan":"No.EV Charge Stations/No. EV charge outlets"})

# Retain State and column 4 ("Electric (stations/charging outlets)"
# Code Ref:  Zach, 9 November 2021, Statology, "How to Select Columns by Index in a Pandas DataFrame", 
# (https://www.statology.org/pandas-select-column-by-index/#:~:text=If%20you'd%20like%20to,loc%20function.), accessed 12 July 2023

evtrim19_df = evbase19_df.iloc[:,[0,4]]

evtrim19_df.head(3)
# Out:
# 0    State No.EV Charge Stations/No. EV charge outlets
# 3  Alabama                                   195 / 506
# 5   Alaska                                     19 / 34
# 7  Arizona                                 522 / 1,476

# %%
# split column 2 by "/" delimeter
# Code Ref:  Zach, 21 July 2021, Statology, "How to Split String Column in Pandas into Multiple Columns", 
# (https://www.statology.org/pandas-split-column/), accessed 12 July 2023

evtrim19_df[["2019 - No.EV Charge Stations", "2019 - No. EV charge outlets"]] = evtrim19_df["No.EV Charge Stations/No. EV charge outlets"].str.split("/", 1, expand=True)

# Delete original 'split' columns 
evclean19_df = evtrim19_df.drop("No.EV Charge Stations/No. EV charge outlets", axis=1)
evclean19_df
# Out:
# /var/folders/m7/yfqdhr1157x_5xx3bb3y5s940000gn/T/ipykernel_3111/2099749085.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   evtrim19_df[["2019 - No.EV Charge Stations", "2019 - No. EV charge outlets"]] = evtrim19_df["No.EV Charge Stations/No. EV charge outlets"].str.split("/", 1, expand=True)
# /var/folders/m7/yfqdhr1157x_5xx3bb3y5s940000gn/T/ipykernel_3111/2099749085.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   evtrim19_df[["2019 - No.EV Charge Stations", "2019 - No. EV charge outlets"]] = evtrim19_df["No.EV Charge Stations/No. EV charge outlets"].str.split("/", 1, expand=True)
# 0                   State 2019 - No.EV Charge Stations  \
# 3                 Alabama                         195
# 5                  Alaska                          19
# 7                 Arizona                         522
# 9                Arkansas                          98
# 11             California                       6,435
# 13               Colorado                         861
# 15            Connecticut                         422
# 17               Delaware                          57
# 19   District of Columbia                         172
# 21                Florida                       1,562
# 23                Georgia                         882
# 25                 Hawaii                         296
# 27                  Idaho                          95
# 29               Illinois                         663
# 31                Indiana                         239
# 33                   Iowa                         141
# 35                 Kansas                         234
# 37               Kentucky                         133
# 39              Louisiana                         107
# 41                  Maine                         184
# 43               Maryland                         738
# 45          Massachusetts                         811
# 47               Michigan                         616
# 49              Minnesota                         380
# 51            Mississippi                          81
# 53               Missouri                         452
# 55                Montana                          55
# 57               Nebraska                          95
# 59                 Nevada                         284
# 61          New Hampshire                         121
# 63             New Jersey                         457
# 65             New Mexico                          82
# 67               New York                       1,655
# 69         North Carolina                         732
# 71           North Dakota                          28
# 73                   Ohio                         540
# 75               Oklahoma                         131
# 77                 Oregon                         721
# 79           Pennsylvania                         572
# 81           Rhode Island                         113
# 83         South Carolina                         286
# 85           South Dakota                          41
# 87              Tennessee                         453
# 89                  Texas                       1,376
# 91                   Utah                         289
# 93                Vermont                         237
# 95               Virginia                         710
# 97             Washington                       1,095
# 99          West Virginia                          89
# 101             Wisconsin                         345
# 103               Wyoming                          57
# 105                 Total                      26,959
#
# 0   2019 - No. EV charge outlets
# 3                            506
# 5                             34
# 7                          1,476
# 9                            290
# 11                        27,128
# 13                         2,516
# 15                         1,048
# 17                           172
# 19                           553
# 21                         4,562
# 23                         2,939
# 25                           666
# 27                           216
# 29                         1,864
# 31                           614
# 33                           348
# 35                           904
# 37                           315
# 39                           293
# 41                           433
# 43                         2,110
# 45                         2,455
# 47                         1,429
# 49                         1,051
# 51                           292
# 53                         1,895
# 55                           137
# 57                           238
# 59                           927
# 61                           244
# 63                         1,297
# 65                           245
# 67                         4,531
# 69                         1,903
# 71                            46
# 73                         1,342
# 75                           309
# 77                         1,893
# 79                         1,475
# 81                           407
# 83                           643
# 85                           127
# 87                         1,207
# 89                         4,009
# 91                           950
# 93                           664
# 95                         2,056
# 97                         3,206
# 99                           244
# 101                          711
# 103                          159
# 105                       85,079

# %%
# Remove last row by index number
# Code Ref:  Zach, 14 may 2021, Statology, "How to drop rows by index in pandas", 
# (https://www.statology.org/pandas-drop-row-by-index/), accessed 12 July 2023

evfinal19_df = evclean19_df.drop(index=[105])

evfinal19_df
# Out:
# 0                   State 2019 - No.EV Charge Stations  \
# 3                 Alabama                         195
# 5                  Alaska                          19
# 7                 Arizona                         522
# 9                Arkansas                          98
# 11             California                       6,435
# 13               Colorado                         861
# 15            Connecticut                         422
# 17               Delaware                          57
# 19   District of Columbia                         172
# 21                Florida                       1,562
# 23                Georgia                         882
# 25                 Hawaii                         296
# 27                  Idaho                          95
# 29               Illinois                         663
# 31                Indiana                         239
# 33                   Iowa                         141
# 35                 Kansas                         234
# 37               Kentucky                         133
# 39              Louisiana                         107
# 41                  Maine                         184
# 43               Maryland                         738
# 45          Massachusetts                         811
# 47               Michigan                         616
# 49              Minnesota                         380
# 51            Mississippi                          81
# 53               Missouri                         452
# 55                Montana                          55
# 57               Nebraska                          95
# 59                 Nevada                         284
# 61          New Hampshire                         121
# 63             New Jersey                         457
# 65             New Mexico                          82
# 67               New York                       1,655
# 69         North Carolina                         732
# 71           North Dakota                          28
# 73                   Ohio                         540
# 75               Oklahoma                         131
# 77                 Oregon                         721
# 79           Pennsylvania                         572
# 81           Rhode Island                         113
# 83         South Carolina                         286
# 85           South Dakota                          41
# 87              Tennessee                         453
# 89                  Texas                       1,376
# 91                   Utah                         289
# 93                Vermont                         237
# 95               Virginia                         710
# 97             Washington                       1,095
# 99          West Virginia                          89
# 101             Wisconsin                         345
# 103               Wyoming                          57
#
# 0   2019 - No. EV charge outlets
# 3                            506
# 5                             34
# 7                          1,476
# 9                            290
# 11                        27,128
# 13                         2,516
# 15                         1,048
# 17                           172
# 19                           553
# 21                         4,562
# 23                         2,939
# 25                           666
# 27                           216
# 29                         1,864
# 31                           614
# 33                           348
# 35                           904
# 37                           315
# 39                           293
# 41                           433
# 43                         2,110
# 45                         2,455
# 47                         1,429
# 49                         1,051
# 51                           292
# 53                         1,895
# 55                           137
# 57                           238
# 59                           927
# 61                           244
# 63                         1,297
# 65                           245
# 67                         4,531
# 69                         1,903
# 71                            46
# 73                         1,342
# 75                           309
# 77                         1,893
# 79                         1,475
# 81                           407
# 83                           643
# 85                           127
# 87                         1,207
# 89                         4,009
# 91                           950
# 93                           664
# 95                         2,056
# 97                         3,206
# 99                           244
# 101                          711
# 103                          159

# %%
# Export the data into a csv
evfinal19_df.to_csv("Resources/Clean_2019_EV_ChargeStation.csv", index_label="Index")
